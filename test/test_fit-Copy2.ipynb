# %%
import sys
sys.path.append("..")
from pathlib import Path
import numpy as np
from scipy import stats
import importlib
import src.assay_calibration.fit_utils.two_sample.fit
from src.assay_calibration.fit_utils.fit import Fit
importlib.reload(src.assay_calibration.fit_utils.two_sample.fit)
importlib.reload(src.assay_calibration.fit_utils.fit)
from src.assay_calibration.fit_utils.two_sample.fit import single_fit
from src.assay_calibration.fit_utils.two_sample import (density_utils,constraints, optimize)
import scipy.stats as sps
import matplotlib
matplotlib.set_loglevel("warning")
import matplotlib.pyplot as plt
import numpy as np
from tqdm.auto import trange
import os
sys.path.append(str(Path(os.getcwd()).parent))
from src.assay_calibration.data_utils.dataset import (
    PillarProjectDataframe,
    Scoreset,
    BasicScoreset,
)
import json
import glob

# %%
# from src.assay_calibration.data_utils.dataset import (
#     PillarProjectDataframe,
#     Scoreset,
#     BasicScoreset,
# )
# ds = Scoreset.from_json("/data/ross/assay_calibration/scoresets/CALM1_CALM2_CALM3_Weile_2017.json")

# %%
# dir(ds)

# %%
# ds.scoreset_name

# %%
# for sample in ds.samples:
#     print(sample[1])
#     # break

# %%
def test_fit(ds, component_range, check_monotonic, init_strategy):
    # Load directly from JSON
    fit = Fit(ds)
    fits = fit.run(
                core_limit=20,
                num_fits=100,
                verbose_level=20,
                component_range=component_range,
                bootstrap=False,
                verbose=False,
                max_em_iters=10000,
                check_convergence=False,
                check_monotonic=check_monotonic,
                submerge_steps=None,#256 if check_monotonic else None,
                init_strategy=init_strategy,
                score_min=ds.scores.min() - 1,
                score_max=ds.scores.max() + 1,
                # kmean_init="k-means++"
            )
    
    return fits, ds

# for dataset_f in glob.glob("/data/ross/assay_calibration/scoresets/*.json"):
    
#     dataset_name = dataset_f.split('/')[-1][:-5]

#     for component_range in ("2-component","3-component"):
#         for monotonicity_contraint in ("no constraint","constraint"):
#             # for init_strategy in ("kmeans","random"):
#             init_strategy = "kmeans"
            
#             fits, ds = test_fit(dataset_f, component_range=[3] if component_range[0] == "3" else [2], 
#                                 check_monotonic=False if monotonicity_contraint[0] == "n" else True, 
#                                 init_strategy=init_strategy)
            
#             fit_results = sorted(fits, key=lambda res: res['likelihoods'][-1], reverse=True)
#             best_fit = fit_results[0]
#             scores = ds.scores
#             sample_assignments = ds.sample_assignments
            
#             score_range = np.linspace(scores.min(), scores.max(), 1000)
#             estimatedDensities = np.array([density_utils.joint_densities(score_range[...,None],
#                                                                          best_fit['component_params'],
#                                                                          sample_weights).squeeze() for sample_weights in best_fit['weights']])
            
#             fig,ax = plt.subplots(3,1, figsize=(12,12))
#             for i in range(3):
#                 ax[i].plot(score_range, estimatedDensities[i].sum(0), label='Estimated', color='C1', linestyle='--')
#                 ax[i].hist(scores[sample_assignments[:,i]], density=True, alpha=0.3, color='gray', label='Data histogram')
#                 ax[i].set_title(f'Sample {i+1}')
#                 ax[i].legend()

# %%
all_results = {}

# %%
#### import matplotlib.pyplot as plt
import glob
import os
import numpy as np

# Create output directory if it doesn't exist
output_dir = "/data/ross/assay_calibration/test_experimental_plots_v6"
os.makedirs(output_dir, exist_ok=True)

# Suppress matplotlib debug messages
import logging
logging.getLogger('matplotlib').setLevel(logging.WARNING)

n_non_violating_fits_without_constraint = 0

for dataset_f in glob.glob("/data/ross/assay_calibration/scoresets/*.json"):
    
    dataset_name = dataset_f.split('/')[-1][:-5]
    print(f"Processing {dataset_name}")

    ds = Scoreset.from_json(dataset_f)
    print(ds)

    sample_names = np.array([sample[1] for sample in ds.samples])
    
    # Create figure with 4x3 subplot grid
    fig, axes = plt.subplots(len(sample_names), 4, figsize=(18, 5*len(sample_names)))
    fig.suptitle(f'Dataset: {dataset_name}', fontsize=16, y=0.995)

    all_results[dataset_name] = {}
    
    plot_idx = 0
    for component_range in ["2-component", "3-component"]:
        for monotonicity_constraint in ["constraint", "no constraint"]:
            # for init_density_fix in ["lambda","sigma"]:
            init_strategy = "random"
            
            # Run the fit
            try:
                fits, ds = test_fit(
                    ds, 
                    component_range=[3] if component_range[0] == "3" else [2], 
                    check_monotonic=False if monotonicity_constraint[0] == "n" else True, 
                    init_strategy=init_strategy
                )
                
                # Get best fit
                fit_results = sorted(fits, key=lambda res: res['likelihoods'][-1], reverse=True)
                best_fit = fit_results[0]
                best_init = "MoM" if best_fit['kmeans'] == "method_of_moments" else "KM"
                xlims = best_fit['xlims']
                scores = ds.scores
                sample_assignments = ds.sample_assignments
    
                
                all_results[dataset_name][(component_range, monotonicity_constraint)] = best_fit
    
                # Calculate densities
                score_range = np.linspace(scores.min(), scores.max(), 1000)
                estimatedDensities = np.array([
                    density_utils.joint_densities(
                        score_range[..., None],
                        best_fit['component_params'],
                        sample_weights
                    ).squeeze() for sample_weights in best_fit['weights']
                ])
                
                # Check if density constraint violated
                fit_violates_constraint = constraints.multicomponent_density_constraint_violated(best_fit['component_params'], xlims)
                if monotonicity_constraint == "no constraint" and fit_violates_constraint:
                    n_non_violating_fits_without_constraint += 1
                fit_violates_constraint = "violates" if fit_violates_constraint else "not violates"
                
                # Plot for each sample (3 columns)
                for i in range(len(estimatedDensities)):
                    ax = axes[i, plot_idx]
                    
                    # Plot estimated density
                    ax.plot(score_range, estimatedDensities[i].sum(0), 
                           label='Estimated', color='C1', linestyle='-', linewidth=2)
                    
                    # Plot histogram of actual data
                    if i < sample_assignments.shape[1] and sample_assignments[:, i].sum() > 0:
                        ax.hist(scores[sample_assignments[:, i]], 
                               bins=30, density=True, alpha=0.3, 
                               color='gray', label='Data')
                    
                    # Set labels and title
                    if plot_idx == 0:
                        ax.set_ylabel(sample_names[i], 
                                     fontsize=12, fontweight='bold')
                    
                    if i == 0:
                        ax.set_title(f'{component_range}, {monotonicity_constraint}, {best_init}, {fit_violates_constraint}', fontsize=12)
                    
                    if i == len(estimatedDensities) - 1:
                        ax.set_xlabel('Score', fontsize=10)
                    
                    ax.legend(loc='upper right', fontsize=8)
                    ax.grid(True, alpha=0.2)
                    
                    # Add likelihood value as text
                    likelihood = best_fit['likelihoods'][-1]
                    ax.text(0.02, 0.98, f'LL: {likelihood:.3f}, n={len(scores[sample_assignments[:, i]])}', 
                           transform=ax.transAxes, fontsize=12,
                           verticalalignment='top')
                
            except Exception as e:
                print(f"  Error with {component_range}, {monotonicity_constraint}: {e}")
                # Create empty plots with error message
                for i in range(len(estimatedDensities)):
                    ax = axes[i, plot_idx]
                    ax.text(0.5, 0.5, f'Error:\n{str(e)[:30]}...', 
                           ha='center', va='center', transform=ax.transAxes)
                    ax.set_xticks([])
                    ax.set_yticks([])

                    if i == 0:
                        ax.set_title(f'{component_range}, {monotonicity_constraint}, {best_init}, {fit_violates_constraint}', fontsize=12)
                    
                    if plot_idx == 0:
                        ax.set_ylabel(sample_names[i], 
                                     fontsize=12, fontweight='bold')
                    
                    if i == len(estimatedDensities) - 1:
                        ax.set_xlabel('Score', fontsize=10)
            
            plot_idx += 1
    
    # Adjust layout and save
    plt.tight_layout(rect=[0, 0, 1, 0.99])
    
    output_path = f"{output_dir}/{dataset_name}.png"
    plt.savefig(output_path, dpi=100, bbox_inches='tight')
    plt.close()
    
    print(f"  Saved to {output_path}")

print("All plots saved!")
# Out:
# Processing ASPA_Grønbæk-Thygesen_2024_abundance
# ASPA_Grønbæk-Thygesen_2024_abundance: 18623 total variants
# 	Pathogenic/Likely Pathogenic: 64 variants
# 	Benign/Likely Benign: 6 variants
# 	gnomAD: 352 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/ASPA_Grønbæk-Thygesen_2024_abundance.png
# Processing ASPA_Grønbæk-Thygesen_2024_toxicity
# ASPA_Grønbæk-Thygesen_2024_toxicity: 18615 total variants
# 	Pathogenic/Likely Pathogenic: 64 variants
# 	Benign/Likely Benign: 6 variants
# 	gnomAD: 352 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/ASPA_Grønbæk-Thygesen_2024_toxicity.png
# Processing BAP1_Waters_2024
# BAP1_Waters_2024: 18108 total variants
# 	Pathogenic/Likely Pathogenic: 197 variants
# 	Benign/Likely Benign: 398 variants
# 	gnomAD: 1369 variants
# 	Synonymous: 1854 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BAP1_Waters_2024.png
# Processing BARD1_unpublished
# BARD1_unpublished: 9128 total variants
# 	Pathogenic/Likely Pathogenic: 185 variants
# 	Benign/Likely Benign: 270 variants
# 	gnomAD: 1614 variants
# 	Synonymous: 1337 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BARD1_unpublished.png
# Processing BRCA1_Adamovich_2022_Cisplatin
# BRCA1_Adamovich_2022_Cisplatin: 5131 total variants
# 	Pathogenic/Likely Pathogenic: 55 variants
# 	Benign/Likely Benign: 25 variants
# 	gnomAD: 115 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA1_Adamovich_2022_Cisplatin.png
# Processing BRCA1_Adamovich_2022_HDR
# BRCA1_Adamovich_2022_HDR: 8122 total variants
# 	Pathogenic/Likely Pathogenic: 58 variants
# 	Benign/Likely Benign: 34 variants
# 	gnomAD: 149 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA1_Adamovich_2022_HDR.png
# Processing BRCA1_Findlay_2018
# BRCA1_Findlay_2018: 3893 total variants
# 	Pathogenic/Likely Pathogenic: 410 variants
# 	Benign/Likely Benign: 270 variants
# 	gnomAD: 599 variants
# 	Synonymous: 544 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA1_Findlay_2018.png
# Processing BRCA2_Hu_2024
# BRCA2_Hu_2024: 444 total variants
# 	Pathogenic/Likely Pathogenic: 48 variants
# 	Benign/Likely Benign: 44 variants
# 	gnomAD: 235 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA2_Hu_2024.png
# Processing BRCA2_Sahu_2023_exon13_Cisplatin
# BRCA2_Sahu_2023_exon13_Cisplatin: 251 total variants
# 	Pathogenic/Likely Pathogenic: 17 variants
# 	Benign/Likely Benign: 9 variants
# 	gnomAD: 46 variants
# 	Synonymous: 39 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA2_Sahu_2023_exon13_Cisplatin.png
# Processing BRCA2_Sahu_2023_exon13_Olaparib
# BRCA2_Sahu_2023_exon13_Olaparib: 251 total variants
# 	Pathogenic/Likely Pathogenic: 17 variants
# 	Benign/Likely Benign: 9 variants
# 	gnomAD: 46 variants
# 	Synonymous: 39 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA2_Sahu_2023_exon13_Olaparib.png
# Processing BRCA2_Sahu_2023_exon13_SGE
# BRCA2_Sahu_2023_exon13_SGE: 251 total variants
# 	Pathogenic/Likely Pathogenic: 17 variants
# 	Benign/Likely Benign: 9 variants
# 	gnomAD: 46 variants
# 	Synonymous: 39 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA2_Sahu_2023_exon13_SGE.png
# Processing BRCA2_Sahu_2023_exon13_global_score
# BRCA2_Sahu_2023_exon13_global_score: 251 total variants
# 	Pathogenic/Likely Pathogenic: 17 variants
# 	Benign/Likely Benign: 9 variants
# 	gnomAD: 46 variants
# 	Synonymous: 39 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA2_Sahu_2023_exon13_global_score.png
# Processing BRCA2_Sahu_2025_HDR
# BRCA2_Sahu_2025_HDR: 6550 total variants
# 	Pathogenic/Likely Pathogenic: 353 variants
# 	Benign/Likely Benign: 71 variants
# 	gnomAD: 938 variants
# 	Synonymous: 1276 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA2_Sahu_2025_HDR.png
# Processing BRCA2_unpublished
# BRCA2_unpublished: 824 total variants
# 	Pathogenic/Likely Pathogenic: 43 variants
# 	Benign/Likely Benign: 20 variants
# 	gnomAD: 111 variants
# 	Synonymous: 154 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/BRCA2_unpublished.png
# Processing CALM1_CALM2_CALM3_Weile_2017
# CALM1_CALM2_CALM3_Weile_2017: 6300 total variants
# 	Pathogenic/Likely Pathogenic: 12 variants
# 	gnomAD: 28 variants
# 	Synonymous: 130 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/CALM1_CALM2_CALM3_Weile_2017.png
# Processing CARD11_Meitlis_2020_DMSO_no_introns
# CARD11_Meitlis_2020_DMSO_no_introns: 3844 total variants
# 	Pathogenic/Likely Pathogenic: 4 variants
# 	gnomAD: 48 variants
# 	Synonymous: 137 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/CARD11_Meitlis_2020_DMSO_no_introns.png
# Processing CARD11_Meitlis_2020_Ibrutinib_no_introns
# CARD11_Meitlis_2020_Ibrutinib_no_introns: 3812 total variants
# 	Pathogenic/Likely Pathogenic: 4 variants
# 	gnomAD: 48 variants
# 	Synonymous: 137 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/CARD11_Meitlis_2020_Ibrutinib_no_introns.png
# Processing CBS_Sun_2020_high_B6
# CBS_Sun_2020_high_B6: 10765 total variants
# 	Pathogenic/Likely Pathogenic: 21 variants
# 	Benign/Likely Benign: 4 variants
# 	gnomAD: 19 variants
# 	Synonymous: 463 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/CBS_Sun_2020_high_B6.png
# Processing CBS_Sun_2020_low_B6
# CBS_Sun_2020_low_B6: 11442 total variants
# 	Pathogenic/Likely Pathogenic: 17 variants
# 	Benign/Likely Benign: 5 variants
# 	gnomAD: 16 variants
# 	Synonymous: 478 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/CBS_Sun_2020_low_B6.png
# Processing CHK2_Gebbia_2024
# CHK2_Gebbia_2024: 27407 total variants
# 	Pathogenic/Likely Pathogenic: 103 variants
# 	Benign/Likely Benign: 10 variants
# 	gnomAD: 665 variants
# 	Synonymous: 386 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/CHK2_Gebbia_2024.png
# Processing CRX_Shepherdson_2024
# CRX_Shepherdson_2024: 15804 total variants
# 	Pathogenic/Likely Pathogenic: 12 variants
# 	Benign/Likely Benign: 8 variants
# 	gnomAD: 349 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/CRX_Shepherdson_2024.png
# Processing CTCF_unpublished
# CTCF_unpublished: 5081 total variants
# 	Pathogenic/Likely Pathogenic: 41 variants
# 	Benign/Likely Benign: 8 variants
# 	gnomAD: 564 variants
# 	Synonymous: 637 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/CTCF_unpublished.png
# Processing DDX3X_Radford_2023_cLFC_day15
# DDX3X_Radford_2023_cLFC_day15: 9080 total variants
# 	Pathogenic/Likely Pathogenic: 201 variants
# 	Benign/Likely Benign: 88 variants
# 	gnomAD: 524 variants
# 	Synonymous: 1245 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/DDX3X_Radford_2023_cLFC_day15.png
# Processing F9_Popp_2025_carboxy_F9_specific
# F9_Popp_2025_carboxy_F9_specific: 26988 total variants
# 	Pathogenic/Likely Pathogenic: 115 variants
# 	Benign/Likely Benign: 21 variants
# 	gnomAD: 229 variants
# 	Synonymous: 418 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/F9_Popp_2025_carboxy_F9_specific.png
# Processing F9_Popp_2025_carboxy_gla_motif
# F9_Popp_2025_carboxy_gla_motif: 26988 total variants
# 	Pathogenic/Likely Pathogenic: 115 variants
# 	Benign/Likely Benign: 21 variants
# 	gnomAD: 229 variants
# 	Synonymous: 418 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/F9_Popp_2025_carboxy_gla_motif.png
# Processing F9_Popp_2025_heavy_chain
# F9_Popp_2025_heavy_chain: 26988 total variants
# 	Pathogenic/Likely Pathogenic: 115 variants
# 	Benign/Likely Benign: 21 variants
# 	gnomAD: 229 variants
# 	Synonymous: 418 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/F9_Popp_2025_heavy_chain.png
# Processing F9_Popp_2025_light_chain
# F9_Popp_2025_light_chain: 26988 total variants
# 	Pathogenic/Likely Pathogenic: 115 variants
# 	Benign/Likely Benign: 21 variants
# 	gnomAD: 229 variants
# 	Synonymous: 418 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/F9_Popp_2025_light_chain.png
# Processing F9_Popp_2025_strep_2
# F9_Popp_2025_strep_2: 26988 total variants
# 	Pathogenic/Likely Pathogenic: 115 variants
# 	Benign/Likely Benign: 21 variants
# 	gnomAD: 229 variants
# 	Synonymous: 418 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/F9_Popp_2025_strep_2.png
# Processing FKRP_Ma_2024
# FKRP_Ma_2024: 4455 total variants
# 	Pathogenic/Likely Pathogenic: 91 variants
# 	Benign/Likely Benign: 2 variants
# 	gnomAD: 858 variants
# 	Synonymous: 1194 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/FKRP_Ma_2024.png
# Processing G6PD_unpublished
# G6PD_unpublished: 31963 total variants
# 	Pathogenic/Likely Pathogenic: 188 variants
# 	Benign/Likely Benign: 6 variants
# 	gnomAD: 317 variants
# 	Synonymous: 468 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/G6PD_unpublished.png
# Processing GCK_Gersing_2023_complementation
# GCK_Gersing_2023_complementation: 28405 total variants
# 	Pathogenic/Likely Pathogenic: 300 variants
# 	Benign/Likely Benign: 7 variants
# 	gnomAD: 441 variants
# 	Synonymous: 347 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/GCK_Gersing_2023_complementation.png
# Processing GCK_Gersing_2024_abundance
# GCK_Gersing_2024_abundance: 28062 total variants
# 	Pathogenic/Likely Pathogenic: 296 variants
# 	Benign/Likely Benign: 9 variants
# 	gnomAD: 443 variants
# 	Synonymous: 365 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/GCK_Gersing_2024_abundance.png
# Processing HMBS_van_Loggerenberg_2023_combined
# HMBS_van_Loggerenberg_2023_combined: 19977 total variants
# 	Pathogenic/Likely Pathogenic: 45 variants
# 	Benign/Likely Benign: 4 variants
# 	gnomAD: 387 variants
# 	Synonymous: 286 variants
#
#   Error with 2-component, no constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Error with 3-component, no constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/HMBS_van_Loggerenberg_2023_combined.png
# Processing HMBS_van_Loggerenberg_2023_erythroid
# HMBS_van_Loggerenberg_2023_erythroid: 19728 total variants
# 	Pathogenic/Likely Pathogenic: 44 variants
# 	Benign/Likely Benign: 4 variants
# 	gnomAD: 382 variants
# 	Synonymous: 277 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/HMBS_van_Loggerenberg_2023_erythroid.png
# Processing HMBS_van_Loggerenberg_2023_ubquitous
# HMBS_van_Loggerenberg_2023_ubquitous: 18499 total variants
# 	Pathogenic/Likely Pathogenic: 39 variants
# 	Benign/Likely Benign: 4 variants
# 	gnomAD: 361 variants
# 	Synonymous: 267 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/HMBS_van_Loggerenberg_2023_ubquitous.png
# Processing JAG1_Gilbert_2024
# JAG1_Gilbert_2024: 2790 total variants
# 	Pathogenic/Likely Pathogenic: 16 variants
# 	Benign/Likely Benign: 11 variants
# 	gnomAD: 279 variants
# 	Synonymous: 630 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/JAG1_Gilbert_2024.png
# Processing KCNE1_Muhammad_2024_absence_of_WT
# KCNE1_Muhammad_2024_absence_of_WT: 7668 total variants
# 	Pathogenic/Likely Pathogenic: 7 variants
# 	Benign/Likely Benign: 2 variants
# 	gnomAD: 53 variants
# 	Synonymous: 97 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/KCNE1_Muhammad_2024_absence_of_WT.png
# Processing KCNE1_Muhammad_2024_potassium_flux
# KCNE1_Muhammad_2024_potassium_flux: 7655 total variants
# 	Pathogenic/Likely Pathogenic: 7 variants
# 	Benign/Likely Benign: 2 variants
# 	gnomAD: 53 variants
# 	Synonymous: 97 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/KCNE1_Muhammad_2024_potassium_flux.png
# Processing KCNE1_Muhammad_2024_presence_of_WT
# KCNE1_Muhammad_2024_presence_of_WT: 7683 total variants
# 	Pathogenic/Likely Pathogenic: 7 variants
# 	Benign/Likely Benign: 2 variants
# 	gnomAD: 53 variants
# 	Synonymous: 97 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/KCNE1_Muhammad_2024_presence_of_WT.png
# Processing KCNH2_Jiang_2022
# KCNH2_Jiang_2022: 281 total variants
# 	Pathogenic/Likely Pathogenic: 22 variants
# 	Benign/Likely Benign: 8 variants
# 	gnomAD: 23 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/KCNH2_Jiang_2022.png
# Processing KCNH2_Kozek_Glazer_2020
# KCNH2_Kozek_Glazer_2020: 672 total variants
# 	Pathogenic/Likely Pathogenic: 3 variants
# 	gnomAD: 10 variants
# 	Synonymous: 9 variants
#
# Iteration 7784: Likelihood decreased by 1.95e-07 (relative: 3.42e-07) - likely numerical rounding error
# Iteration 7785: Likelihood decreased by 4.36e-07 (relative: 7.65e-07) - likely numerical rounding error
# Iteration 7786: Likelihood DECREASED by 7.24e-07 (relative: 1.27e-06) - algorithmic issue
# Iteration 7990: Likelihood decreased by 1.36e-07 (relative: 2.38e-07) - likely numerical rounding error
# Iteration 7991: Likelihood decreased by 3.62e-07 (relative: 6.34e-07) - likely numerical rounding error
# Iteration 7992: Likelihood DECREASED by 6.33e-07 (relative: 1.11e-06) - algorithmic issue
# Iteration 7546: Likelihood decreased by 9.88e-08 (relative: 1.73e-07) - likely numerical rounding error
# Iteration 7547: Likelihood decreased by 3.24e-07 (relative: 5.67e-07) - likely numerical rounding error
# Iteration 7548: Likelihood DECREASED by 5.94e-07 (relative: 1.04e-06) - algorithmic issue
# Iteration 7281: Likelihood decreased by 2.02e-07 (relative: 3.54e-07) - likely numerical rounding error
# Iteration 7282: Likelihood decreased by 4.52e-07 (relative: 7.93e-07) - likely numerical rounding error
# Iteration 7283: Likelihood DECREASED by 7.50e-07 (relative: 1.31e-06) - algorithmic issue
# Iteration 7950: Likelihood decreased by 1.79e-08 (relative: 3.13e-08) - likely numerical rounding error
# Iteration 7951: Likelihood decreased by 2.19e-07 (relative: 3.83e-07) - likely numerical rounding error
# Iteration 7952: Likelihood decreased by 4.62e-07 (relative: 8.09e-07) - likely numerical rounding error
# Iteration 7953: Likelihood DECREASED by 7.52e-07 (relative: 1.32e-06) - algorithmic issue
# Iteration 7982: Likelihood decreased by 3.28e-08 (relative: 5.74e-08) - likely numerical rounding error
# Iteration 7983: Likelihood decreased by 2.36e-07 (relative: 4.14e-07) - likely numerical rounding error
# Iteration 7984: Likelihood decreased by 4.83e-07 (relative: 8.46e-07) - likely numerical rounding error
# Iteration 7985: Likelihood DECREASED by 7.77e-07 (relative: 1.36e-06) - algorithmic issue
# Iteration 9950: Likelihood decreased by 3.26e-08 (relative: 5.54e-08) - likely numerical rounding error
# Iteration 9951: Likelihood decreased by 7.49e-08 (relative: 1.27e-07) - likely numerical rounding error
# Iteration 9952: Likelihood decreased by 1.21e-07 (relative: 2.06e-07) - likely numerical rounding error
# Iteration 9953: Likelihood decreased by 1.72e-07 (relative: 2.93e-07) - likely numerical rounding error
# Iteration 9954: Likelihood decreased by 2.28e-07 (relative: 3.87e-07) - likely numerical rounding error
# Iteration 9955: Likelihood decreased by 2.88e-07 (relative: 4.90e-07) - likely numerical rounding error
# Iteration 9956: Likelihood decreased by 3.54e-07 (relative: 6.02e-07) - likely numerical rounding error
# Iteration 9957: Likelihood decreased by 4.26e-07 (relative: 7.24e-07) - likely numerical rounding error
# Iteration 9958: Likelihood decreased by 5.04e-07 (relative: 8.56e-07) - likely numerical rounding error
# Iteration 9959: Likelihood decreased by 5.88e-07 (relative: 1.00e-06) - likely numerical rounding error
# Iteration 9960: Likelihood DECREASED by 6.79e-07 (relative: 1.15e-06) - algorithmic issue
# Iteration 7516: Likelihood decreased by 5.84e-08 (relative: 1.02e-07) - likely numerical rounding error
# Iteration 7517: Likelihood decreased by 2.75e-07 (relative: 4.83e-07) - likely numerical rounding error
# Iteration 7518: Likelihood decreased by 5.37e-07 (relative: 9.40e-07) - likely numerical rounding error
# Iteration 7519: Likelihood DECREASED by 8.46e-07 (relative: 1.48e-06) - algorithmic issue
# Iteration 7469: Likelihood decreased by 1.60e-08 (relative: 2.80e-08) - likely numerical rounding error
# Iteration 7470: Likelihood decreased by 2.25e-07 (relative: 3.94e-07) - likely numerical rounding error
# Iteration 7471: Likelihood decreased by 4.77e-07 (relative: 8.35e-07) - likely numerical rounding error
# Iteration 7472: Likelihood DECREASED by 7.76e-07 (relative: 1.36e-06) - algorithmic issue
# Iteration 7970: Likelihood decreased by 1.08e-09 (relative: 1.90e-09) - likely numerical rounding error
# Iteration 7971: Likelihood decreased by 1.98e-07 (relative: 3.46e-07) - likely numerical rounding error
# Iteration 7972: Likelihood decreased by 4.36e-07 (relative: 7.65e-07) - likely numerical rounding error
# Iteration 7973: Likelihood DECREASED by 7.22e-07 (relative: 1.26e-06) - algorithmic issue
# Iteration 5270: Likelihood DECREASED by 1.78e-07 (relative: 2.04e-06) - algorithmic issue
# Iteration 7960: Likelihood decreased by 7.48e-08 (relative: 1.31e-07) - likely numerical rounding error
# Iteration 7961: Likelihood decreased by 2.88e-07 (relative: 5.04e-07) - likely numerical rounding error
# Iteration 7962: Likelihood decreased by 5.45e-07 (relative: 9.54e-07) - likely numerical rounding error
# Iteration 7963: Likelihood DECREASED by 8.50e-07 (relative: 1.49e-06) - algorithmic issue
# Iteration 7488: Likelihood decreased by 7.79e-08 (relative: 1.36e-07) - likely numerical rounding error
# Iteration 7489: Likelihood decreased by 2.99e-07 (relative: 5.25e-07) - likely numerical rounding error
# Iteration 7490: Likelihood decreased by 5.66e-07 (relative: 9.92e-07) - likely numerical rounding error
# Iteration 7491: Likelihood DECREASED by 8.81e-07 (relative: 1.54e-06) - algorithmic issue
# Iteration 7974: Likelihood decreased by 3.11e-08 (relative: 5.44e-08) - likely numerical rounding error
# Iteration 7975: Likelihood decreased by 2.34e-07 (relative: 4.10e-07) - likely numerical rounding error
# Iteration 7976: Likelihood decreased by 4.80e-07 (relative: 8.42e-07) - likely numerical rounding error
# Iteration 7977: Likelihood DECREASED by 7.74e-07 (relative: 1.36e-06) - algorithmic issue
# Iteration 6662: Likelihood DECREASED by 1.21e-06 (relative: 1.41e-05) - algorithmic issue
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/KCNH2_Kozek_Glazer_2020.png
# Processing KCNH2_O_Neill_2024_surface_expression
# KCNH2_O_Neill_2024_surface_expression: 68540 total variants
# 	Pathogenic/Likely Pathogenic: 198 variants
# 	Benign/Likely Benign: 13 variants
# 	gnomAD: 1243 variants
# 	Synonymous: 1003 variants
#
#   Error with 2-component, no constraint: 'xlims'
# Iteration 7034: Likelihood decreased by 2.33e-08 (relative: 4.09e-08) - likely numerical rounding error
# Iteration 7035: Likelihood decreased by 2.41e-07 (relative: 4.23e-07) - likely numerical rounding error
# Iteration 7036: Likelihood decreased by 5.04e-07 (relative: 8.82e-07) - likely numerical rounding error
# Iteration 7037: Likelihood DECREASED by 8.14e-07 (relative: 1.43e-06) - algorithmic issue
# Iteration 7533: Likelihood decreased by 2.01e-07 (relative: 3.53e-07) - likely numerical rounding error
# Iteration 7534: Likelihood decreased by 4.48e-07 (relative: 7.84e-07) - likely numerical rounding error
# Iteration 7535: Likelihood DECREASED by 7.41e-07 (relative: 1.30e-06) - algorithmic issue
# Iteration 7489: Likelihood decreased by 1.08e-07 (relative: 1.90e-07) - likely numerical rounding error
# Iteration 7490: Likelihood decreased by 3.36e-07 (relative: 5.89e-07) - likely numerical rounding error
# Iteration 7491: Likelihood DECREASED by 6.10e-07 (relative: 1.07e-06) - algorithmic issue
# Iteration 7951: Likelihood decreased by 1.87e-08 (relative: 3.28e-08) - likely numerical rounding error
# Iteration 7952: Likelihood decreased by 2.20e-07 (relative: 3.85e-07) - likely numerical rounding error
# Iteration 7953: Likelihood decreased by 4.63e-07 (relative: 8.11e-07) - likely numerical rounding error
# Iteration 7954: Likelihood DECREASED by 7.54e-07 (relative: 1.32e-06) - algorithmic issue
# Iteration 993: Likelihood DECREASED by 9.47e-08 (relative: 1.07e-06) - algorithmic issue
# Iteration 1: Likelihood DECREASED by 1.39e-02 (relative: 9.18e-04) - algorithmic issue
# Iteration 4707: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4719: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4755: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4721: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4701: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4756: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4691: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4702: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4714: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4696: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 7394: Likelihood decreased by 3.43e-08 (relative: 6.02e-08) - likely numerical rounding error
# Iteration 7395: Likelihood decreased by 2.48e-07 (relative: 4.35e-07) - likely numerical rounding error
# Iteration 7396: Likelihood decreased by 5.06e-07 (relative: 8.87e-07) - likely numerical rounding error
# Iteration 7397: Likelihood DECREASED by 8.12e-07 (relative: 1.42e-06) - algorithmic issue
# Iteration 7935: Likelihood decreased by 1.84e-07 (relative: 3.23e-07) - likely numerical rounding error
# Iteration 7936: Likelihood decreased by 4.21e-07 (relative: 7.38e-07) - likely numerical rounding error
# Iteration 7937: Likelihood DECREASED by 7.04e-07 (relative: 1.23e-06) - algorithmic issue
# Iteration 3445: Likelihood decreased by 8.38e-08 (relative: 1.47e-07) - likely numerical rounding error
# Iteration 3446: Likelihood decreased by 3.92e-07 (relative: 6.87e-07) - likely numerical rounding error
# Iteration 3447: Likelihood DECREASED by 7.37e-07 (relative: 1.29e-06) - algorithmic issue
# Iteration 4755: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4734: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4763: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4750: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4701: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 7943: Likelihood decreased by 1.29e-07 (relative: 2.26e-07) - likely numerical rounding error
# Iteration 7944: Likelihood decreased by 3.54e-07 (relative: 6.20e-07) - likely numerical rounding error
# Iteration 7945: Likelihood DECREASED by 6.24e-07 (relative: 1.09e-06) - algorithmic issue
# Iteration 7538: Likelihood decreased by 6.29e-09 (relative: 1.10e-08) - likely numerical rounding error
# Iteration 7539: Likelihood decreased by 2.12e-07 (relative: 3.71e-07) - likely numerical rounding error
# Iteration 7540: Likelihood decreased by 4.60e-07 (relative: 8.06e-07) - likely numerical rounding error
# Iteration 7541: Likelihood DECREASED by 7.56e-07 (relative: 1.32e-06) - algorithmic issue
# Iteration 4750: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4723: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4692: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4702: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4753: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 8055: Likelihood decreased by 2.55e-07 (relative: 4.47e-07) - likely numerical rounding error
# Iteration 8056: Likelihood DECREASED by 6.28e-07 (relative: 1.10e-06) - algorithmic issue
# Iteration 7483: Likelihood decreased by 4.79e-08 (relative: 8.39e-08) - likely numerical rounding error
# Iteration 7484: Likelihood decreased by 2.63e-07 (relative: 4.61e-07) - likely numerical rounding error
# Iteration 7485: Likelihood decreased by 5.23e-07 (relative: 9.16e-07) - likely numerical rounding error
# Iteration 7486: Likelihood DECREASED by 8.30e-07 (relative: 1.45e-06) - algorithmic issue
# Iteration 7543: Likelihood decreased by 1.10e-07 (relative: 1.92e-07) - likely numerical rounding error
# Iteration 7544: Likelihood decreased by 3.37e-07 (relative: 5.91e-07) - likely numerical rounding error
# Iteration 7545: Likelihood DECREASED by 6.10e-07 (relative: 1.07e-06) - algorithmic issue
# Iteration 7546: Likelihood decreased by 1.07e-07 (relative: 1.87e-07) - likely numerical rounding error
# Iteration 7547: Likelihood decreased by 3.33e-07 (relative: 5.84e-07) - likely numerical rounding error
# Iteration 7548: Likelihood DECREASED by 6.05e-07 (relative: 1.06e-06) - algorithmic issue
# Iteration 845: Likelihood DECREASED by 2.57e-07 (relative: 2.98e-06) - algorithmic issue
# Iteration 1492: Likelihood DECREASED by 3.86e-07 (relative: 4.39e-06) - algorithmic issue
# Iteration 5010: Likelihood DECREASED by 1.07e-06 (relative: 1.26e-05) - algorithmic issue
# Iteration 6266: Likelihood DECREASED by 1.10e-06 (relative: 4.03e-05) - algorithmic issue
# Iteration 4691: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4766: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4764: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4751: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4700: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 7568: Likelihood decreased by 8.13e-08 (relative: 1.42e-07) - likely numerical rounding error
# Iteration 7569: Likelihood decreased by 3.02e-07 (relative: 5.30e-07) - likely numerical rounding error
# Iteration 7570: Likelihood decreased by 5.68e-07 (relative: 9.95e-07) - likely numerical rounding error
# Iteration 7571: Likelihood DECREASED by 8.83e-07 (relative: 1.55e-06) - algorithmic issue
# Iteration 8344: Likelihood decreased by 1.64e-07 (relative: 2.88e-07) - likely numerical rounding error
# Iteration 8345: Likelihood decreased by 3.91e-07 (relative: 6.85e-07) - likely numerical rounding error
# Iteration 8346: Likelihood DECREASED by 6.63e-07 (relative: 1.16e-06) - algorithmic issue
# Iteration 7986: Likelihood decreased by 1.34e-07 (relative: 2.34e-07) - likely numerical rounding error
# Iteration 7987: Likelihood decreased by 3.59e-07 (relative: 6.29e-07) - likely numerical rounding error
# Iteration 7988: Likelihood DECREASED by 6.29e-07 (relative: 1.10e-06) - algorithmic issue
# Iteration 7559: Likelihood decreased by 1.09e-07 (relative: 1.92e-07) - likely numerical rounding error
# Iteration 7560: Likelihood decreased by 3.36e-07 (relative: 5.89e-07) - likely numerical rounding error
# Iteration 7561: Likelihood DECREASED by 6.09e-07 (relative: 1.07e-06) - algorithmic issue
# Iteration 791: Likelihood DECREASED by 1.18e-06 (relative: 1.36e-05) - algorithmic issue
# Iteration 4693: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4719: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4689: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4756: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4702: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 7971: Likelihood decreased by 8.96e-09 (relative: 1.57e-08) - likely numerical rounding error
# Iteration 7972: Likelihood decreased by 2.07e-07 (relative: 3.63e-07) - likely numerical rounding error
# Iteration 7973: Likelihood decreased by 4.48e-07 (relative: 7.85e-07) - likely numerical rounding error
# Iteration 7974: Likelihood DECREASED by 7.35e-07 (relative: 1.29e-06) - algorithmic issue
# Iteration 3290: Likelihood decreased by 2.80e-07 (relative: 4.91e-07) - likely numerical rounding error
# Iteration 3291: Likelihood DECREASED by 6.13e-07 (relative: 1.07e-06) - algorithmic issue
# Iteration 7976: Likelihood decreased by 3.71e-08 (relative: 6.51e-08) - likely numerical rounding error
# Iteration 7977: Likelihood decreased by 2.42e-07 (relative: 4.23e-07) - likely numerical rounding error
# Iteration 7978: Likelihood decreased by 4.89e-07 (relative: 8.57e-07) - likely numerical rounding error
# Iteration 7979: Likelihood DECREASED by 7.84e-07 (relative: 1.37e-06) - algorithmic issue
# Iteration 7565: Likelihood decreased by 8.66e-08 (relative: 1.52e-07) - likely numerical rounding error
# Iteration 7566: Likelihood decreased by 3.09e-07 (relative: 5.41e-07) - likely numerical rounding error
# Iteration 7567: Likelihood DECREASED by 5.76e-07 (relative: 1.01e-06) - algorithmic issue
# Iteration 4760: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4755: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4699: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4700: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4756: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 7874: Likelihood decreased by 1.19e-07 (relative: 2.08e-07) - likely numerical rounding error
# Iteration 7875: Likelihood decreased by 3.42e-07 (relative: 6.00e-07) - likely numerical rounding error
# Iteration 7876: Likelihood DECREASED by 6.11e-07 (relative: 1.07e-06) - algorithmic issue
# Iteration 7548: Likelihood decreased by 1.40e-07 (relative: 2.45e-07) - likely numerical rounding error
# Iteration 7549: Likelihood decreased by 3.74e-07 (relative: 6.55e-07) - likely numerical rounding error
# Iteration 7550: Likelihood DECREASED by 6.53e-07 (relative: 1.14e-06) - algorithmic issue
# Iteration 7550: Likelihood decreased by 4.67e-08 (relative: 8.18e-08) - likely numerical rounding error
# Iteration 7551: Likelihood decreased by 2.61e-07 (relative: 4.57e-07) - likely numerical rounding error
# Iteration 7552: Likelihood decreased by 5.18e-07 (relative: 9.08e-07) - likely numerical rounding error
# Iteration 7553: Likelihood DECREASED by 8.24e-07 (relative: 1.44e-06) - algorithmic issue
# Iteration 4757: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4762: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4773: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4744: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4751: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 9104: Likelihood decreased by 9.31e-08 (relative: 1.63e-07) - likely numerical rounding error
# Iteration 9105: Likelihood decreased by 2.94e-07 (relative: 5.16e-07) - likely numerical rounding error
# Iteration 9106: Likelihood decreased by 5.38e-07 (relative: 9.43e-07) - likely numerical rounding error
# Iteration 9107: Likelihood DECREASED by 8.30e-07 (relative: 1.45e-06) - algorithmic issue
# Iteration 7595: Likelihood DECREASED by 3.02e-07 (relative: 1.86e-06) - algorithmic issue
# Iteration 732: Likelihood DECREASED by 1.98e-06 (relative: 2.29e-05) - algorithmic issue
# Iteration 4761: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4705: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4769: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4702: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4691: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4687: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4700: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4690: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4721: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4725: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4721: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4696: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4756: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4700: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4754: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 7558: Likelihood decreased by 6.02e-09 (relative: 1.05e-08) - likely numerical rounding error
# Iteration 7559: Likelihood decreased by 2.11e-07 (relative: 3.70e-07) - likely numerical rounding error
# Iteration 7560: Likelihood decreased by 4.59e-07 (relative: 8.04e-07) - likely numerical rounding error
# Iteration 7561: Likelihood DECREASED by 7.54e-07 (relative: 1.32e-06) - algorithmic issue
# Iteration 7543: Likelihood decreased by 4.55e-08 (relative: 7.98e-08) - likely numerical rounding error
# Iteration 7544: Likelihood decreased by 2.59e-07 (relative: 4.54e-07) - likely numerical rounding error
# Iteration 7545: Likelihood decreased by 5.17e-07 (relative: 9.06e-07) - likely numerical rounding error
# Iteration 7546: Likelihood DECREASED by 8.23e-07 (relative: 1.44e-06) - algorithmic issue
# Iteration 7538: Likelihood decreased by 1.25e-07 (relative: 2.19e-07) - likely numerical rounding error
# Iteration 7539: Likelihood decreased by 3.56e-07 (relative: 6.24e-07) - likely numerical rounding error
# Iteration 7540: Likelihood DECREASED by 6.32e-07 (relative: 1.11e-06) - algorithmic issue
# Iteration 846: Likelihood decreased by 3.21e-08 (relative: 3.64e-07) - likely numerical rounding error
# Iteration 847: Likelihood DECREASED by 2.51e-07 (relative: 2.85e-06) - algorithmic issue
# Iteration 4756: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4753: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4969: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4703: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4760: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4762: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4703: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4760: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4684: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4620: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 7557: Likelihood decreased by 5.62e-08 (relative: 9.85e-08) - likely numerical rounding error
# Iteration 7558: Likelihood decreased by 2.72e-07 (relative: 4.77e-07) - likely numerical rounding error
# Iteration 7559: Likelihood decreased by 5.32e-07 (relative: 9.32e-07) - likely numerical rounding error
# Iteration 7560: Likelihood DECREASED by 8.40e-07 (relative: 1.47e-06) - algorithmic issue
# Iteration 7957: Likelihood decreased by 4.15e-08 (relative: 7.27e-08) - likely numerical rounding error
# Iteration 7958: Likelihood decreased by 2.47e-07 (relative: 4.33e-07) - likely numerical rounding error
# Iteration 7959: Likelihood decreased by 4.96e-07 (relative: 8.69e-07) - likely numerical rounding error
# Iteration 7960: Likelihood DECREASED by 7.93e-07 (relative: 1.39e-06) - algorithmic issue
# Iteration 8007: Likelihood decreased by 1.72e-07 (relative: 3.02e-07) - likely numerical rounding error
# Iteration 8008: Likelihood decreased by 4.05e-07 (relative: 7.10e-07) - likely numerical rounding error
# Iteration 8009: Likelihood DECREASED by 6.84e-07 (relative: 1.20e-06) - algorithmic issue
# Iteration 7083: Likelihood DECREASED by 1.85e-07 (relative: 2.12e-06) - algorithmic issue
# Iteration 4689: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4757: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4966: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4711: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4753: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4753: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4752: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4755: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4753: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4698: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4763: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4753: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4753: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4699: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4757: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 7969: Likelihood decreased by 1.41e-07 (relative: 2.48e-07) - likely numerical rounding error
# Iteration 7970: Likelihood decreased by 3.68e-07 (relative: 6.45e-07) - likely numerical rounding error
# Iteration 7971: Likelihood DECREASED by 6.41e-07 (relative: 1.12e-06) - algorithmic issue
# Iteration 4723: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4686: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4702: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
# Iteration 4687: Likelihood DECREASED by 5.50e-02 (relative: 3.70e-03) - algorithmic issue
# Iteration 4708: Likelihood DECREASED by 5.50e-02 (relative: 3.71e-03) - algorithmic issue
#   Error with 3-component, no constraint: 'xlims'
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/KCNH2_O_Neill_2024_surface_expression.png
# Processing KCNQ4_Zheng_2022_current_homozygous
# KCNQ4_Zheng_2022_current_homozygous: 4035 total variants
# 	Pathogenic/Likely Pathogenic: 14 variants
# 	Benign/Likely Benign: 9 variants
# 	gnomAD: 845 variants
# 	Synonymous: 27 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/KCNQ4_Zheng_2022_current_homozygous.png
# Processing KCNQ4_Zheng_2022_v12_homozygous
# KCNQ4_Zheng_2022_v12_homozygous: 3287 total variants
# 	Pathogenic/Likely Pathogenic: 1 variants
# 	Benign/Likely Benign: 9 variants
# 	gnomAD: 748 variants
# 	Synonymous: 27 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/KCNQ4_Zheng_2022_v12_homozygous.png
# Processing LARGE1_Ma_2024
# LARGE1_Ma_2024: 6804 total variants
# 	Pathogenic/Likely Pathogenic: 9 variants
# 	Benign/Likely Benign: 6 variants
# 	gnomAD: 892 variants
# 	Synonymous: 1530 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/LARGE1_Ma_2024.png
# Processing MSH2_Jia_2021
# MSH2_Jia_2021: 51682 total variants
# 	Pathogenic/Likely Pathogenic: 106 variants
# 	Benign/Likely Benign: 231 variants
# 	gnomAD: 1353 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/MSH2_Jia_2021.png
# Processing NDUFAF6_Sung_2024
# NDUFAF6_Sung_2024: 17210 total variants
# 	Pathogenic/Likely Pathogenic: 6 variants
# 	Benign/Likely Benign: 6 variants
# 	gnomAD: 347 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/NDUFAF6_Sung_2024.png
# Processing OTC_Lo_2023
# OTC_Lo_2023: 5251 total variants
# 	Pathogenic/Likely Pathogenic: 79 variants
# 	Benign/Likely Benign: 7 variants
# 	gnomAD: 139 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/OTC_Lo_2023.png
# Processing PALB2_unpublished
# PALB2_unpublished: 8729 total variants
# 	Pathogenic/Likely Pathogenic: 277 variants
# 	Benign/Likely Benign: 170 variants
# 	gnomAD: 1374 variants
# 	Synonymous: 1513 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/PALB2_unpublished.png
# Processing PAX6_McDonnell_2024_BLX_geneticin
# PAX6_McDonnell_2024_BLX_geneticin: 8626 total variants
# 	Pathogenic/Likely Pathogenic: 48 variants
# 	Benign/Likely Benign: 1 variants
# 	gnomAD: 96 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/PAX6_McDonnell_2024_BLX_geneticin.png
# Processing PAX6_McDonnell_2024_BLX_no_geneticin
# PAX6_McDonnell_2024_BLX_no_geneticin: 8609 total variants
# 	Pathogenic/Likely Pathogenic: 48 variants
# 	Benign/Likely Benign: 1 variants
# 	gnomAD: 96 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/PAX6_McDonnell_2024_BLX_no_geneticin.png
# Processing PAX6_McDonnell_2024_LE9_geneticin
# PAX6_McDonnell_2024_LE9_geneticin: 8669 total variants
# 	Pathogenic/Likely Pathogenic: 48 variants
# 	Benign/Likely Benign: 1 variants
# 	gnomAD: 96 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/PAX6_McDonnell_2024_LE9_geneticin.png
# Processing PAX6_McDonnell_2024_LE9_no_geneticin
# PAX6_McDonnell_2024_LE9_no_geneticin: 8669 total variants
# 	Pathogenic/Likely Pathogenic: 48 variants
# 	Benign/Likely Benign: 1 variants
# 	gnomAD: 96 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/PAX6_McDonnell_2024_LE9_no_geneticin.png
# Processing PTEN_Matreyek_2018
# PTEN_Matreyek_2018: 14570 total variants
# 	Pathogenic/Likely Pathogenic: 145 variants
# 	Benign/Likely Benign: 7 variants
# 	gnomAD: 142 variants
# 	Synonymous: 146 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/PTEN_Matreyek_2018.png
# Processing PTEN_Mighell_2018
# PTEN_Mighell_2018: 17351 total variants
# 	Pathogenic/Likely Pathogenic: 199 variants
# 	Benign/Likely Benign: 5 variants
# 	gnomAD: 181 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/PTEN_Mighell_2018.png
# Processing RAD51C_Olvera-León_2024_z_score_D4_D14
# RAD51C_Olvera-León_2024_z_score_D4_D14: 8836 total variants
# 	Pathogenic/Likely Pathogenic: 199 variants
# 	Benign/Likely Benign: 192 variants
# 	gnomAD: 792 variants
# 	Synonymous: 908 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/RAD51C_Olvera-León_2024_z_score_D4_D14.png
# Processing RAD51D_unpublished
# RAD51D_unpublished: 4525 total variants
# 	Pathogenic/Likely Pathogenic: 76 variants
# 	Benign/Likely Benign: 196 variants
# 	gnomAD: 728 variants
# 	Synonymous: 656 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/RAD51D_unpublished.png
# Processing RHO_Wan_2019
# RHO_Wan_2019: 204 total variants
# 	Pathogenic/Likely Pathogenic: 85 variants
# 	Benign/Likely Benign: 3 variants
# 	gnomAD: 66 variants
# 	Synonymous: 12 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/RHO_Wan_2019.png
# Processing SCN5A_Glazer_2020
# SCN5A_Glazer_2020: 751 total variants
# 	Pathogenic/Likely Pathogenic: 8 variants
# 	gnomAD: 16 variants
# 	Synonymous: 12 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/SCN5A_Glazer_2020.png
# Processing SCN5A_Ma_2024_current_density
# SCN5A_Ma_2024_current_density: 159 total variants
# 	Pathogenic/Likely Pathogenic: 15 variants
# 	Benign/Likely Benign: 12 variants
# 	gnomAD: 40 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/SCN5A_Ma_2024_current_density.png
# Processing SFPQ_unpublished
# SFPQ_unpublished: 2285 total variants
# 	gnomAD: 274 variants
# 	Synonymous: 366 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/SFPQ_unpublished.png
# Processing SGCB_Li_2023
# SGCB_Li_2023: 18098 total variants
# 	Pathogenic/Likely Pathogenic: 12 variants
# 	gnomAD: 443 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/SGCB_Li_2023.png
# Processing TARDBP_Bolognesi_Faure_2019
# TARDBP_Bolognesi_Faure_2019: 4149 total variants
# 	Pathogenic/Likely Pathogenic: 12 variants
# 	gnomAD: 61 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TARDBP_Bolognesi_Faure_2019.png
# Processing TP53_Boettcher_2019
# TP53_Boettcher_2019: 23667 total variants
# 	Pathogenic/Likely Pathogenic: 240 variants
# 	Benign/Likely Benign: 105 variants
# 	gnomAD: 483 variants
# 	Synonymous: 35 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Boettcher_2019.png
# Processing TP53_Fayer_2021_meta
# TP53_Fayer_2021_meta: 23667 total variants
# 	Pathogenic/Likely Pathogenic: 240 variants
# 	Benign/Likely Benign: 105 variants
# 	gnomAD: 483 variants
# 	Synonymous: 35 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Fayer_2021_meta.png
# Processing TP53_Fortuno_2021_Kato_meta
# TP53_Fortuno_2021_Kato_meta: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
#   Error with 3-component, constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Fortuno_2021_Kato_meta.png
# Processing TP53_Giacomelli_2018_combined_score
# TP53_Giacomelli_2018_combined_score: 24655 total variants
# 	Pathogenic/Likely Pathogenic: 240 variants
# 	Benign/Likely Benign: 111 variants
# 	gnomAD: 487 variants
# 	Synonymous: 358 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Giacomelli_2018_combined_score.png
# Processing TP53_Giacomelli_2018_p53WT_Nutlin3
# TP53_Giacomelli_2018_p53WT_Nutlin3: 24655 total variants
# 	Pathogenic/Likely Pathogenic: 240 variants
# 	Benign/Likely Benign: 111 variants
# 	gnomAD: 487 variants
# 	Synonymous: 358 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Giacomelli_2018_p53WT_Nutlin3.png
# Processing TP53_Giacomelli_2018_p53null_Nutlin3
# TP53_Giacomelli_2018_p53null_Nutlin3: 24655 total variants
# 	Pathogenic/Likely Pathogenic: 240 variants
# 	Benign/Likely Benign: 111 variants
# 	gnomAD: 487 variants
# 	Synonymous: 358 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Giacomelli_2018_p53null_Nutlin3.png
# Processing TP53_Giacomelli_2018_p53null_etoposide
# TP53_Giacomelli_2018_p53null_etoposide: 24655 total variants
# 	Pathogenic/Likely Pathogenic: 240 variants
# 	Benign/Likely Benign: 111 variants
# 	gnomAD: 487 variants
# 	Synonymous: 358 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Giacomelli_2018_p53null_etoposide.png
# Processing TP53_Kato_2003_AIP1nWT
# TP53_Kato_2003_AIP1nWT: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
# Iteration 564: Likelihood DECREASED by 1.72e-04 (relative: 3.84e-05) - algorithmic issue
# Iteration 541: Likelihood DECREASED by 1.03e-03 (relative: 2.30e-04) - algorithmic issue
# Iteration 416: Likelihood DECREASED by 1.55e-04 (relative: 3.46e-05) - algorithmic issue
# Iteration 674: Likelihood DECREASED by 3.89e-04 (relative: 8.71e-05) - algorithmic issue
# Iteration 652: Likelihood DECREASED by 1.75e-03 (relative: 3.91e-04) - algorithmic issue
# Iteration 653: Likelihood DECREASED by 2.35e-05 (relative: 5.27e-06) - algorithmic issue
# Iteration 4711: Likelihood DECREASED by 6.02e-02 (relative: 3.59e-03) - algorithmic issue
# Iteration 4652: Likelihood DECREASED by 6.02e-02 (relative: 3.58e-03) - algorithmic issue
# Iteration 4708: Likelihood DECREASED by 6.02e-02 (relative: 3.58e-03) - algorithmic issue
# Iteration 803: Likelihood DECREASED by 6.75e-04 (relative: 1.51e-04) - algorithmic issue
# Iteration 733: Likelihood DECREASED by 1.46e-03 (relative: 3.26e-04) - algorithmic issue
# Iteration 4707: Likelihood DECREASED by 6.02e-02 (relative: 3.58e-03) - algorithmic issue
# Iteration 413: Likelihood DECREASED by 3.41e-04 (relative: 7.63e-05) - algorithmic issue
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Kato_2003_AIP1nWT.png
# Processing TP53_Kato_2003_BAXnWT
# TP53_Kato_2003_BAXnWT: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
# Iteration 2481: Likelihood DECREASED by 7.40e-05 (relative: 1.70e-05) - algorithmic issue
# Iteration 534: Likelihood DECREASED by 1.57e-04 (relative: 3.51e-05) - algorithmic issue
# Iteration 8160: Likelihood decreased by 5.33e-08 (relative: 1.23e-08) - likely numerical rounding error
# Iteration 8161: Likelihood decreased by 2.03e-07 (relative: 4.68e-08) - likely numerical rounding error
# Iteration 8162: Likelihood decreased by 3.84e-07 (relative: 8.85e-08) - likely numerical rounding error
# Iteration 8163: Likelihood decreased by 6.01e-07 (relative: 1.39e-07) - likely numerical rounding error
# Iteration 8164: Likelihood decreased by 8.62e-07 (relative: 1.99e-07) - likely numerical rounding error
# Iteration 8165: Likelihood decreased by 1.17e-06 (relative: 2.71e-07) - likely numerical rounding error
# Iteration 8166: Likelihood decreased by 1.55e-06 (relative: 3.57e-07) - likely numerical rounding error
# Iteration 8167: Likelihood decreased by 1.99e-06 (relative: 4.59e-07) - likely numerical rounding error
# Iteration 8168: Likelihood decreased by 2.52e-06 (relative: 5.81e-07) - likely numerical rounding error
# Iteration 8169: Likelihood decreased by 3.15e-06 (relative: 7.26e-07) - likely numerical rounding error
# Iteration 8170: Likelihood decreased by 3.90e-06 (relative: 8.98e-07) - likely numerical rounding error
# Iteration 8171: Likelihood DECREASED by 4.78e-06 (relative: 1.10e-06) - algorithmic issue
# Iteration 53: Likelihood decreased by 8.88e-16 (relative: 1.78e-16) - likely numerical rounding error
# Iteration 2706: Likelihood decreased by 8.88e-16 (relative: 1.80e-16) - likely numerical rounding error
# Iteration 4036: Likelihood decreased by 2.11e-07 (relative: 4.85e-08) - likely numerical rounding error
# Iteration 4037: Likelihood decreased by 1.19e-06 (relative: 2.75e-07) - likely numerical rounding error
# Iteration 4038: Likelihood decreased by 2.41e-06 (relative: 5.54e-07) - likely numerical rounding error
# Iteration 4039: Likelihood decreased by 3.88e-06 (relative: 8.95e-07) - likely numerical rounding error
# Iteration 4040: Likelihood DECREASED by 5.66e-06 (relative: 1.31e-06) - algorithmic issue
# Iteration 4663: Likelihood DECREASED by 7.34e-02 (relative: 3.40e-03) - algorithmic issue
# Iteration 4651: Likelihood DECREASED by 7.34e-02 (relative: 3.40e-03) - algorithmic issue
# Iteration 4688: Likelihood DECREASED by 7.34e-02 (relative: 3.40e-03) - algorithmic issue
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Kato_2003_BAXnWT.png
# Processing TP53_Kato_2003_GADD45nWT
# TP53_Kato_2003_GADD45nWT: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Kato_2003_GADD45nWT.png
# Processing TP53_Kato_2003_MDM2nWT
# TP53_Kato_2003_MDM2nWT: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
# Iteration 1930: Likelihood DECREASED by 4.37e-05 (relative: 9.12e-06) - algorithmic issue
# Iteration 343: Likelihood DECREASED by 6.68e-06 (relative: 1.52e-06) - algorithmic issue
# Iteration 337: Likelihood DECREASED by 6.68e-06 (relative: 1.52e-06) - algorithmic issue
# Iteration 422: Likelihood decreased by 2.30e-07 (relative: 5.24e-08) - likely numerical rounding error
# Iteration 423: Likelihood DECREASED by 3.02e-05 (relative: 6.88e-06) - algorithmic issue
# Iteration 64: Likelihood DECREASED by 5.76e-06 (relative: 1.31e-06) - algorithmic issue
# Iteration 67: Likelihood DECREASED by 1.61e-04 (relative: 3.65e-05) - algorithmic issue
# Iteration 910: Likelihood DECREASED by 1.27e-04 (relative: 2.65e-05) - algorithmic issue
# Iteration 405: Likelihood DECREASED by 8.45e-06 (relative: 1.92e-06) - algorithmic issue
# Iteration 414: Likelihood DECREASED by 1.66e-05 (relative: 3.78e-06) - algorithmic issue
# Iteration 226: Likelihood DECREASED by 3.26e-05 (relative: 7.40e-06) - algorithmic issue
# Iteration 971: Likelihood DECREASED by 2.19e-04 (relative: 4.57e-05) - algorithmic issue
# Iteration 928: Likelihood DECREASED by 3.76e-05 (relative: 7.84e-06) - algorithmic issue
# Iteration 79: Likelihood DECREASED by 1.40e-04 (relative: 3.17e-05) - algorithmic issue
# Iteration 98: Likelihood DECREASED by 3.04e-04 (relative: 6.90e-05) - algorithmic issue
# Iteration 303: Likelihood DECREASED by 1.08e-05 (relative: 2.49e-06) - algorithmic issue
# Iteration 504: Likelihood DECREASED by 2.06e-05 (relative: 4.28e-06) - algorithmic issue
# Iteration 1112: Likelihood DECREASED by 4.07e-04 (relative: 8.49e-05) - algorithmic issue
# Iteration 253: Likelihood DECREASED by 6.71e-06 (relative: 1.53e-06) - algorithmic issue
# Iteration 296: Likelihood DECREASED by 1.09e-05 (relative: 2.48e-06) - algorithmic issue
# Iteration 386: Likelihood decreased by 3.44e-06 (relative: 7.82e-07) - likely numerical rounding error
# Iteration 387: Likelihood DECREASED by 3.94e-05 (relative: 8.96e-06) - algorithmic issue
# Iteration 685: Likelihood DECREASED by 6.89e-05 (relative: 1.44e-05) - algorithmic issue
# Iteration 59: Likelihood DECREASED by 7.10e-06 (relative: 1.61e-06) - algorithmic issue
# Iteration 98: Likelihood DECREASED by 3.04e-04 (relative: 6.90e-05) - algorithmic issue
# Iteration 1125: Likelihood decreased by 8.88e-16 (relative: 1.82e-16) - likely numerical rounding error
# Iteration 602: Likelihood DECREASED by 8.47e-06 (relative: 1.76e-06) - algorithmic issue
# Iteration 919: Likelihood DECREASED by 1.13e-04 (relative: 2.36e-05) - algorithmic issue
# Iteration 4542: Likelihood DECREASED by 3.57e-02 (relative: 4.58e-03) - algorithmic issue
# Iteration 215: Likelihood DECREASED by 4.21e-05 (relative: 9.58e-06) - algorithmic issue
# Iteration 304: Likelihood DECREASED by 4.71e-06 (relative: 1.07e-06) - algorithmic issue
# Iteration 957: Likelihood DECREASED by 6.50e-04 (relative: 1.36e-04) - algorithmic issue
# Iteration 393: Likelihood decreased by 1.32e-06 (relative: 2.76e-07) - likely numerical rounding error
# Iteration 394: Likelihood decreased by 2.97e-06 (relative: 6.19e-07) - likely numerical rounding error
# Iteration 395: Likelihood decreased by 4.70e-06 (relative: 9.81e-07) - likely numerical rounding error
# Iteration 396: Likelihood DECREASED by 6.53e-06 (relative: 1.36e-06) - algorithmic issue
# Iteration 863: Likelihood DECREASED by 5.76e-05 (relative: 1.20e-05) - algorithmic issue
# Iteration 73: Likelihood DECREASED by 1.33e-05 (relative: 3.02e-06) - algorithmic issue
# Iteration 74: Likelihood DECREASED by 9.44e-05 (relative: 2.14e-05) - algorithmic issue
# Iteration 94: Likelihood DECREASED by 1.45e-04 (relative: 3.30e-05) - algorithmic issue
# Iteration 315: Likelihood DECREASED by 2.52e-05 (relative: 5.74e-06) - algorithmic issue
# Iteration 405: Likelihood DECREASED by 8.45e-06 (relative: 1.92e-06) - algorithmic issue
# Iteration 350: Likelihood DECREASED by 2.41e-05 (relative: 5.48e-06) - algorithmic issue
# Iteration 236: Likelihood DECREASED by 9.79e-05 (relative: 2.25e-05) - algorithmic issue
# Iteration 861: Likelihood DECREASED by 2.77e-05 (relative: 5.77e-06) - algorithmic issue
# Iteration 935: Likelihood DECREASED by 9.77e-05 (relative: 2.04e-05) - algorithmic issue
# Iteration 558: Likelihood DECREASED by 7.11e-05 (relative: 1.48e-05) - algorithmic issue
# Iteration 1216: Likelihood DECREASED by 2.24e-04 (relative: 4.66e-05) - algorithmic issue
# Iteration 417: Likelihood DECREASED by 1.16e-05 (relative: 2.65e-06) - algorithmic issue
# Iteration 204: Likelihood decreased by 8.88e-16 (relative: 1.96e-16) - likely numerical rounding error
# Iteration 68: Likelihood DECREASED by 1.04e-04 (relative: 2.37e-05) - algorithmic issue
# Iteration 368: Likelihood DECREASED by 9.92e-06 (relative: 2.26e-06) - algorithmic issue
# Iteration 345: Likelihood DECREASED by 1.27e-05 (relative: 2.88e-06) - algorithmic issue
# Iteration 356: Likelihood decreased by 3.77e-06 (relative: 8.57e-07) - likely numerical rounding error
# Iteration 357: Likelihood DECREASED by 4.17e-05 (relative: 9.50e-06) - algorithmic issue
# Iteration 98: Likelihood DECREASED by 3.04e-04 (relative: 6.90e-05) - algorithmic issue
# Iteration 82: Likelihood DECREASED by 1.70e-04 (relative: 3.86e-05) - algorithmic issue
# Iteration 63: Likelihood DECREASED by 7.43e-05 (relative: 1.69e-05) - algorithmic issue
# Iteration 296: Likelihood DECREASED by 1.09e-05 (relative: 2.48e-06) - algorithmic issue
# Iteration 378: Likelihood DECREASED by 2.43e-05 (relative: 5.53e-06) - algorithmic issue
# Iteration 942: Likelihood DECREASED by 5.54e-05 (relative: 1.15e-05) - algorithmic issue
# Iteration 401: Likelihood DECREASED by 2.39e-05 (relative: 5.45e-06) - algorithmic issue
# Iteration 416: Likelihood DECREASED by 1.71e-05 (relative: 3.88e-06) - algorithmic issue
# Iteration 257: Likelihood DECREASED by 3.88e-05 (relative: 8.82e-06) - algorithmic issue
# Iteration 78: Likelihood DECREASED by 2.56e-04 (relative: 5.82e-05) - algorithmic issue
# Iteration 981: Likelihood DECREASED by 3.94e-04 (relative: 8.22e-05) - algorithmic issue
# Iteration 4647: Likelihood DECREASED by 3.57e-02 (relative: 4.58e-03) - algorithmic issue
# Iteration 307: Likelihood DECREASED by 1.50e-05 (relative: 3.41e-06) - algorithmic issue
# Iteration 94: Likelihood DECREASED by 1.45e-04 (relative: 3.30e-05) - algorithmic issue
# Iteration 187: Likelihood decreased by 3.54e-06 (relative: 8.12e-07) - likely numerical rounding error
# Iteration 1059: Likelihood DECREASED by 4.84e-04 (relative: 1.01e-04) - algorithmic issue
# Iteration 315: Likelihood DECREASED by 2.52e-05 (relative: 5.74e-06) - algorithmic issue
# Iteration 577: Likelihood decreased by 8.88e-16 (relative: 1.82e-16) - likely numerical rounding error
# Iteration 349: Likelihood DECREASED by 2.53e-05 (relative: 5.76e-06) - algorithmic issue
# Iteration 1017: Likelihood DECREASED by 1.91e-04 (relative: 3.98e-05) - algorithmic issue
# Iteration 701: Likelihood DECREASED by 1.99e-04 (relative: 4.16e-05) - algorithmic issue
# Iteration 662: Likelihood DECREASED by 1.02e-04 (relative: 2.12e-05) - algorithmic issue
# Iteration 170: Likelihood DECREASED by 1.71e-05 (relative: 3.88e-06) - algorithmic issue
# Iteration 379: Likelihood DECREASED by 7.86e-06 (relative: 1.79e-06) - algorithmic issue
# Iteration 363: Likelihood decreased by 1.27e-06 (relative: 2.88e-07) - likely numerical rounding error
# Iteration 364: Likelihood DECREASED by 3.52e-05 (relative: 8.00e-06) - algorithmic issue
#   Error with 3-component, no constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Kato_2003_MDM2nWT.png
# Processing TP53_Kato_2003_NOXAnWT
# TP53_Kato_2003_NOXAnWT: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
#   Error with 2-component, constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Error with 3-component, constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Error with 3-component, no constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Kato_2003_NOXAnWT.png
# Processing TP53_Kato_2003_P53R2nWT
# TP53_Kato_2003_P53R2nWT: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
# Iteration 1190: Likelihood decreased by 3.55e-15 (relative: 7.29e-16) - likely numerical rounding error
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Kato_2003_P53R2nWT.png
# Processing TP53_Kato_2003_WAF1nWT
# TP53_Kato_2003_WAF1nWT: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
#   Error with 3-component, constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Kato_2003_WAF1nWT.png
# Processing TP53_Kato_2003_h1433snWT
# TP53_Kato_2003_h1433snWT: 8248 total variants
# 	Pathogenic/Likely Pathogenic: 180 variants
# 	Benign/Likely Benign: 107 variants
# 	gnomAD: 482 variants
#
#   Error with 3-component, constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Error with 3-component, no constraint: The truth value of an empty array is ambiguous. Use `array.size > 0` to check that an array is not empty.
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TP53_Kato_2003_h1433snWT.png
# Processing TPK1_Weile_2017
# TPK1_Weile_2017: 10874 total variants
# 	Pathogenic/Likely Pathogenic: 4 variants
# 	Benign/Likely Benign: 1 variants
# 	gnomAD: 259 variants
# 	Synonymous: 222 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TPK1_Weile_2017.png
# Processing TSC2_rapgap_unpublished
# TSC2_rapgap_unpublished: 16873 total variants
# 	Pathogenic/Likely Pathogenic: 49 variants
# 	Benign/Likely Benign: 34 variants
# 	gnomAD: 406 variants
# 	Synonymous: 224 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TSC2_rapgap_unpublished.png
# Processing TSC2_tuberin_unpublished
# TSC2_tuberin_unpublished: 10802 total variants
# 	Pathogenic/Likely Pathogenic: 12 variants
# 	Benign/Likely Benign: 24 variants
# 	gnomAD: 280 variants
# 	Synonymous: 120 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/TSC2_tuberin_unpublished.png
# Processing VHL_Buckley_2024
# VHL_Buckley_2024: 2268 total variants
# 	Pathogenic/Likely Pathogenic: 198 variants
# 	Benign/Likely Benign: 56 variants
# 	gnomAD: 344 variants
# 	Synonymous: 375 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/VHL_Buckley_2024.png
# Processing XRCC2_unpublished
# XRCC2_unpublished: 2957 total variants
# 	Pathogenic/Likely Pathogenic: 6 variants
# 	Benign/Likely Benign: 46 variants
# 	gnomAD: 514 variants
# 	Synonymous: 458 variants
#
#   Saved to /data/ross/assay_calibration/test_experimental_plots_v6/XRCC2_unpublished.png
# All plots saved!

# %%
n_non_violating_fits_without_constraint = [0,0]
n_violating_fits_without_constraint = [0,0]
for dataset_f in glob.glob("/data/ross/assay_calibration/scoresets/*.json"):
    dataset_name = dataset_f.split('/')[-1][:-5]
    for i,component_range in enumerate(["2-component", "3-component"]):
        for monotonicity_constraint in ["constraint", "no constraint"]:
            if (component_range,monotonicity_constraint) not in all_results[dataset_name]:
                continue
            params = all_results[dataset_name][(component_range,monotonicity_constraint)]['component_params']
            xlims = all_results[dataset_name][(component_range,monotonicity_constraint)]['xlims']
            fit_violates_constraint = constraints.multicomponent_density_constraint_violated(params, xlims)
            if monotonicity_constraint == "no constraint" and fit_violates_constraint:
                n_violating_fits_without_constraint[i] += 1
            elif monotonicity_constraint == "no constraint":
                n_non_violating_fits_without_constraint[i] += 1

for i,component_range in enumerate(["2-component", "3-component"]):
    print(f'{component_range}: {100*n_non_violating_fits_without_constraint[i]/(n_non_violating_fits_without_constraint[i]+n_violating_fits_without_constraint[i]):.1f}% ({n_non_violating_fits_without_constraint[i]}/{n_non_violating_fits_without_constraint[i]+n_violating_fits_without_constraint[i]}) did not violate the constraint.')
# Out:
# 2-component: 44.4% (36/81) did not violate the constraint.
# 3-component: 12.8% (10/78) did not violate the constraint.

# %%
temp = 0

temp
# Out:
# 166

# %%
# ds = Scoreset.from_json('/data/ross/assay_calibration/scoresets/BAP1_Waters_2024.json')
# constraints.multicomponent_density_constraint_violated(
#     all_results['BAP1_Waters_2024'][('3-component','constraint')]['component_params'],
#     (ds.scores.min(), ds.scores.max())
# ), all_results['BAP1_Waters_2024'][('3-component','constraint')]['component_params']

# %%
# 'HMBS_van_Loggerenberg_2023_combined', 'TP53_Fortuno_2021_Kato_meta' truth value of arr
# 'KCNH2_Jiang_2022', 'KCNH2_O_Neill_2024_surface_expression' ll decreased consistently & xlims

# %%
constraints.multicomponent_density_constraint_violated(best_fit['component_params'],
                                                       score_range[[0,-1]])
# Out:
# True

# %%
best_fit.keys()
# Out:
# dict_keys(['component_params', 'weights', 'likelihoods', 'history', 'kmeans'])

# %%
best_fit['component_params']
# Out:
# [(-8.553172420104763, 0.7949678509378952, 0.24375170761527565),
#  (-1.4489019235176928, 0.9296749533938731, 0.04216918377139136),
#  (-7.860341896888932e-05, 1.003620376681616, 0.020770124957920067)]

# %%
scores.min(),scores.max()
# Out:
# (np.float64(-0.483185729440366), np.float64(1.36169269063829))

# %%
# Iteration 9618: Likelihood DECREASED by 1.96e-06 (relative: 3.51e-06) - algorithmic issue
